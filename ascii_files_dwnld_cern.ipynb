# %%
# %config Completer.use_jedi = False

from bs4 import BeautifulSoup 
import requests
from selenium import webdriver
import time

# %%
url = "https://cernbox.cern.ch/index.php/s/x5kzJXdOG2z7FRU"

# %%
driver = webdriver.Firefox(executable_path="/Users/lucamasserano/Desktop/uni/bocconi/Business Analytics/geckodriver")
driver.get(url)

# %%
content = driver.page_source
soup = BeautifulSoup(content, "lxml")
file_list = soup.find("tbody", id="fileList").find_all("tr")

# %%
len(file_list)
# Out:
# 3547

# %%
for i in range(1, 3549):
    try:
        driver.find_element_by_xpath(f"/html/body/data/div[2]/div/div/table/tbody/tr[{i}]/td[1]/a").click()
    except Exception as e:
        print(i)
# Out:
# 3002
# 3003
# 3004
# 3005
# 3006
# 3007
# 3008
# 3009
# 3010
# 3011
# 3012
# 3013
# 3014
# 3015
# 3016
# 3017
# 3018
# 3019
# 3020
# 3021
# 3022
# 3023
# 3024
# 3025
# 3026
# 3027
# 3028
# 3029
# 3030
# 3031
# 3032
# 3033
# 3034
# 3035
# 3036
# 3037
# 3038
# 3039
# 3040
# 3041
# 3042
# 3043
# 3044
# 3045
# 3046
# 3047
# 3048
# 3049
# 3050
# 3051
# 3052
# 3053
# 3054
# 3055
# 3056
# 3057
# 3058
# 3059
# 3060
# 3061
# 3062
# 3063
# 3064
# 3065
# 3066
# 3067
# 3068
# 3069
# 3070
# 3071
# 3072
# 3073
# 3074
# 3075
# 3076
# 3077
# 3078
# 3079
# 3080
# 3081
# 3082
# 3083
# 3084
# 3085
# 3086
# 3087
# 3088
# 3089
# 3090
# 3091
# 3092
# 3093
# 3094
# 3095
# 3096
# 3097
# 3098
# 3099
# 3100
# 3101
# 3102
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
# 3111
# 3112
# 3113
# 3114
# 3115
# 3116
# 3117
# 3118
# 3119
# 3120
# 3121
# 3122
# 3123
# 3124
# 3125
# 3126
# 3127
# 3128
# 3129
# 3130
# 3131
# 3132
# 3133
# 3134
# 3135
# 3136
# 3137
# 3138
# 3139
# 3140
# 3141
# 3142
# 3143
# ...
